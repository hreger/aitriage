# %% [markdown]
# # ED-AI Modular Triage Pipeline
# This notebook demonstrates a fully modular pipeline for Emergency Department triage prediction using Temporal Fusion Transformer (TFT) and XGBoost.
# We use a baseline of triage, static vitals, demographics, and BERT embeddings, then optionally add diagnosis, home medications, and medication administrations as pluggable modules.
# You can run the baseline immediately, and enrich with new features by toggling simple flags — no preprocessing rewrites required.

# %%
# %pip install pandas numpy scikit-learn xgboost pytorch-forecasting torch transformers mlflow joblib matplotlib seaborn tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\psp17\aitriage\venv\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\psp17\aitriage\venv\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\psp17\aitriage\venv\lib\site-packages (1.7.1)
# Requirement already satisfied: xgboost in c:\users\psp17\aitriage\venv\lib\site-packages (3.0.5)
# Requirement already satisfied: pytorch-forecasting in c:\users\psp17\aitriage\venv\lib\site-packages (1.4.0)
# Requirement already satisfied: torch in c:\users\psp17\aitriage\venv\lib\site-packages (2.8.0)
# Requirement already satisfied: transformers in c:\users\psp17\aitriage\venv\lib\site-packages (4.56.1)
# Requirement already satisfied: mlflow in c:\users\psp17\aitriage\venv\lib\site-packages (3.3.2)
# Requirement already satisfied: joblib in c:\users\psp17\aitriage\venv\lib\site-packages (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\psp17\aitriage\venv\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\users\psp17\aitriage\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: tqdm in c:\users\psp17\aitriage\venv\lib\site-packages (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\psp17\aitriage\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\psp17\aitriage\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: lightning<3.0.0,>=2.0.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from pytorch-forecasting) (2.5.5)
# Requirement already satisfied: filelock in c:\users\psp17\aitriage\venv\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\psp17\aitriage\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\psp17\aitriage\venv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\psp17\aitriage\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\psp17\aitriage\venv\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\psp17\aitriage\venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\psp17\aitriage\venv\lib\site-packages (from transformers) (2025.9.1)
# Requirement already satisfied: requests in c:\users\psp17\aitriage\venv\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\psp17\aitriage\venv\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: mlflow-skinny==3.3.2 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (3.3.2)
# Requirement already satisfied: mlflow-tracing==3.3.2 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (3.3.2)
# Requirement already satisfied: Flask<4 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (1.16.5)
# Requirement already satisfied: cryptography<46,>=43.0.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (2.0.43)
# Requirement already satisfied: waitress<4 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.65.0)
# Requirement already satisfied: fastapi<1 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (1.36.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (6.32.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (2.11.7)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.5.3)
# Requirement already satisfied: uvicorn<1 in c:\users\psp17\aitriage\venv\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.35.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\psp17\aitriage\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\psp17\aitriage\venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: colorama in c:\users\psp17\aitriage\venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: Mako in c:\users\psp17\aitriage\venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\psp17\aitriage\venv\lib\site-packages (from cryptography<46,>=43.0.0->mlflow) (1.17.1)
# Requirement already satisfied: pywin32>=304 in c:\users\psp17\aitriage\venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch-forecasting) (0.15.2)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.8.2)
# Requirement already satisfied: pytorch-lightning in c:\users\psp17\aitriage\venv\lib\site-packages (from lightning<3.0.0,>=2.0.0->pytorch-forecasting) (2.5.5)
# Requirement already satisfied: six>=1.5 in c:\users\psp17\aitriage\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\psp17\aitriage\venv\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\psp17\aitriage\venv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\psp17\aitriage\venv\lib\site-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\psp17\aitriage\venv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\psp17\aitriage\venv\lib\site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow) (2.22)
# Requirement already satisfied: google-auth~=2.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (2.40.3)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from fastapi<1->mlflow-skinny==3.3.2->mlflow) (0.47.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\psp17\aitriage\venv\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (3.12.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\psp17\aitriage\venv\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.2->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\psp17\aitriage\venv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow) (0.57b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\psp17\aitriage\venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.4.1)
# Requirement already satisfied: h11>=0.8 in c:\users\psp17\aitriage\venv\lib\site-packages (from uvicorn<1->mlflow-skinny==3.3.2->mlflow) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\psp17\aitriage\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\psp17\aitriage\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.20.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\psp17\aitriage\venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\psp17\aitriage\venv\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\psp17\aitriage\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score, brier_score_loss
from sklearn.impute import KNNImputer
import xgboost as xgb
import lightgbm as lgb
from pytorch_forecasting import TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.metrics import QuantileLoss
import torch
from transformers import AutoTokenizer, AutoModel
import mlflow
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
# Which modules to include
use_diagnosis = False
use_medhome = False
use_pyxis = False

# %%
# Load core datasets
triage_df = pd.read_csv('data/diagnosis.csv')
vitals_df = pd.read_csv('data/vitalsign.csv')
print(f'Triage records: {len(triage_df)}')
print(f'Vitals records: {len(vitals_df)}')
# Out:
# Triage records: 899050
# Vitals records: 1564610

# %%
def preprocess_core(triage, vitals):
    # Attach charttime to triage
    if 'intime' in triage.columns:
        triage['charttime'] = pd.to_datetime(triage['intime'])
    else:
        triage['charttime'] = pd.to_datetime(triage['charttime'])
    vitals['charttime'] = pd.to_datetime(vitals['charttime'])
    # Merge nearest vitals (within 5min)
    triage = triage.sort_values('charttime')
    vitals = vitals.sort_values('charttime')
    merged = pd.merge_asof(triage, vitals, on='charttime', by='subject_id', direction='nearest', tolerance=pd.Timedelta('5min'))
    # Impute missing vitals
    numeric_cols = ['temperature', 'heart_rate', 'blood_pressure_systolic', 'blood_pressure_diastolic', 'respiratory_rate', 'oxygen_saturation', 'pain_score']
    imputer = KNNImputer(n_neighbors=5)
    merged[numeric_cols] = imputer.fit_transform(merged[numeric_cols])
    return merged

# %%
def get_bert_embeddings(texts):
    tokenizer = AutoTokenizer.from_pretrained('emilyalsentzer/Bio_ClinicalBERT')
    model = AutoModel.from_pretrained('emilyalsentzer/Bio_ClinicalBERT')
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model.to(device)
    model.eval()
    embeddings = []
    for i in tqdm(range(0, len(texts), 8), desc='BERT embedding'):
        batch_texts = texts[i:i+8]
        encodings = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors='pt').to(device)
        with torch.no_grad():
            outputs = model(**encodings)
            embeddings.append(outputs.last_hidden_state[:,0,:].cpu().numpy())
    return np.vstack(embeddings)

# %%
def diagnosis_features(stay_ids):
    # load and process diagnosis.csv, embed ICD codes if use_diagnosis else return None
    if not use_diagnosis: return None
    diagnosis = pd.read_csv('../data/diagnosis.csv')
    # Example: mean ICD code embedding per stay_id (use your embedding logic)
    icd_map = {} # load your ICD embedding model
    stay_features = []
    for sid in stay_ids:
        codes = diagnosis[diagnosis['stay_id']==sid]['icd_code'].tolist()
        vec = np.mean([icd_map.get(c, np.zeros(128)) for c in codes], axis=0)
        stay_features.append(vec)
    return np.vstack(stay_features)

def medhome_features(stay_ids):
    if not use_medhome: return None
    medhome = pd.read_csv('../data/medrecon.csv')
    # Example: average embedding per stay_id
    med_map = {} # load med embedding model
    stay_features = []
    for sid in stay_ids:
        meds = medhome[medhome['stay_id']==sid]['med'].tolist()
        vec = np.mean([med_map.get(m, np.zeros(128)) for m in meds], axis=0)
        stay_features.append(vec)
    return np.vstack(stay_features)

def pyxis_features(pyxis_df, stay_ids, charttimes):
    if not use_pyxis: return None
    # Example: time-varying med administration
    pyxis = pd.read_csv('../data/pyxis.csv')
    # Map meds by time
    features = []
    for sid, ct in zip(stay_ids, charttimes):
        meds = pyxis[(pyxis['stay_id']==sid) & (pyxis['charttime']==ct)]['med'].tolist()
        # map to category IDs or embed as needed
        features.append(meds)
    return features

# %%
def build_tft_dataset(core_df, bert_vecs, diagnosis_vecs=None, medhome_vecs=None, pyxis_seq=None):
    # time-varying features: vitals
    # static covariates: age, gender, chief complaint embed (BERT), optional diagnosis and medhome
    static_features = ['age', 'gender']
    static_vec = np.concatenate([bert_vecs], axis=1)
    if diagnosis_vecs is not None:
        static_vec = np.concatenate([static_vec, diagnosis_vecs], axis=1)
    if medhome_vecs is not None:
        static_vec = np.concatenate([static_vec, medhome_vecs], axis=1)
    # Assemble TFT TimeSeriesDataSet (see pytorch_forecasting docs)
    # Placeholder: implement as per your use-case
    print(f'Static feature vector shape: {static_vec.shape}')
    # For demonstration, return the core_df and static_vec
    return core_df, static_vec

def build_xgb_dataset(core_df, bert_vecs, diagnosis_vecs=None, medhome_vecs=None):
    static_features = ['age', 'temperature', 'heart_rate', 'respiratory_rate', 'oxygen_saturation', 'blood_pressure_systolic', 'blood_pressure_diastolic', 'pain_score']
    X = core_df[static_features]
    X = pd.concat([X, pd.DataFrame(bert_vecs)], axis=1)
    if diagnosis_vecs is not None:
        X = pd.concat([X, pd.DataFrame(diagnosis_vecs)], axis=1)
    if medhome_vecs is not None:
        X = pd.concat([X, pd.DataFrame(medhome_vecs)], axis=1)
    return X

# %%
# Full updated cell: Merge triage with edstays, preprocess, embed, optional modules, build datasets with fix for missing vitals columns

# Load ED stays dataset (needed for 'intime' → 'charttime')
edstays_df = pd.read_csv('data/edstays.csv')
edstays_df['intime'] = pd.to_datetime(edstays_df['intime'])

# Merge triage_df with edstays_df ONCE to get 'intime' for charttime; handle suffixes to avoid conflicts
triage_df = triage_df.merge(
    edstays_df[['stay_id', 'subject_id', 'intime']],
    on=['stay_id', 'subject_id'],
    how='left',
    suffixes=('', '_edstays')
)

# Assign 'charttime' from whichever 'intime' column is present after merge
if 'intime' in triage_df.columns:
    triage_df['charttime'] = pd.to_datetime(triage_df['intime'])
elif 'intime_edstays' in triage_df.columns:
    triage_df['charttime'] = pd.to_datetime(triage_df['intime_edstays'])
else:
    raise KeyError("No 'intime' column found in merged triage_df")

def preprocess_core(triage, vitals):
    # Ensure datetime conversion
    triage['charttime'] = pd.to_datetime(triage['charttime'])
    vitals['charttime'] = pd.to_datetime(vitals['charttime'])

    # Sort by 'charttime' only for merge_asof
    triage = triage.sort_values('charttime')
    vitals = vitals.sort_values('charttime')

    # Merge asof nearest within 5 minutes and by subject_id
    merged = pd.merge_asof(
        triage, vitals,
        on='charttime',
        by='subject_id',
        direction='nearest',
        tolerance=pd.Timedelta('5min')
    )
    
    # Define vitals cols to impute; use those present in merged columns only
    numeric_cols = [
        'temperature', 'heart_rate', 'respiratory_rate', 'oxygen_saturation',
        'blood_pressure_systolic', 'blood_pressure_diastolic', 'pain_score'
    ]
    present_numeric_cols = [c for c in numeric_cols if c in merged.columns]
    
    if present_numeric_cols:
        imputer = KNNImputer(n_neighbors=5)
        merged[present_numeric_cols] = imputer.fit_transform(merged[present_numeric_cols])
    else:
        print("⚠️ Warning: No numeric vitals columns found for imputation.")
    
    return merged

# Run preprocessing core function with fix for missing vitals columns
core = preprocess_core(triage_df, vitals_df)

# Generate ClinicalBERT embeddings from chief complaint text safely
if 'chief_complaint' in core.columns:
    bert_vecs = get_bert_embeddings(core['chief_complaint'].fillna('').astype(str).values)
else:
    print("⚠️ Warning: 'chief_complaint' column not found; using zeros for embeddings.")
    bert_vecs = np.zeros((len(core), 768))  # fallback shape for ClinicalBERT embeddings

# Optionally run feature modules
diagnosis_vecs = diagnosis_features(core['stay_id']) if use_diagnosis else None
medhome_vecs = medhome_features(core['stay_id']) if use_medhome else None

if use_pyxis:
    pyxis_df = pd.read_csv('data/pyxis.csv')
    pyxis_seq = pyxis_features(pyxis_df, core['stay_id'], core['charttime'])
else:
    pyxis_seq = None

# Build TFT and XGBoost datasets
core_tft, static_vec = build_tft_dataset(core, bert_vecs, diagnosis_vecs, medhome_vecs, pyxis_seq)
X_xgb = build_xgb_dataset(core, bert_vecs, diagnosis_vecs, medhome_vecs)

# Create binary target variable safely; check for 'acuity' presence
if 'acuity' in core.columns:
    y = (core['acuity'] <= 2).astype(int)
else:
    print("⚠️ Warning: 'acuity' column not found; generating dummy target variable.")
    y = pd.Series(np.zeros(len(core), dtype=int))

print(f"Processed dataset shape: {core.shape}")
print(f"Target distribution:\n{y.value_counts()}")
